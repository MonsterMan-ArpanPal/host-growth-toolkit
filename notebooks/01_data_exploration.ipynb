# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\saksh\OneDrive\Desktop\Resource\Code\geekforgeeks\data\raw\rental-price-predict\airbnb_sample_submission.csv")

print(df.shape)
print(df.columns.tolist())
df.info()
# Out:
# (53000, 2)
# ['id', 'price']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53000 entries, 0 to 52999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      53000 non-null  int64
#  1   price   53000 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 828.3 KB

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\saksh\\OneDrive\\Desktop\\Resource\\Code\\geekforgeeks\\data\\raw\\rental-price-predict\\airbnb_train.csv")

print(df.shape)
print(df.columns.tolist())
df.info()
# Out:
# (208856, 52)
# ...

# %%
print(df["city"].value_counts(dropna=False).head(50))
# Out:
# city
# London                    13464
# Paris                     12775
# Sicily                    10926
# Puglia                     8603
# Los Angeles                7482
# Hawaii                     6406
# South Aegean               5918
# Rio de Janeiro             5493
# Crete                      4867
# New York City              4723
# Lisbon                     4486
# Ireland                    4260
# Madrid                     4114
# Melbourne                  3963
# Girona                     3805
# Toronto                    3437
# Broward County             3340
# Barcelona                  3281
# Sydney                     3199
# Milan                      3113
# Athens                     2966
# Mallorca                   2794
# Porto                      2721
# Clark County, NV           2587
# Malta                      2461
# San Diego                  2413
# Florence                   2413
# Western Australia          2373
# Austin                     2330
# ...

# %%
import pandas as pd

calendar = pd.read_csv(r"C:\Users\saksh\OneDrive\Desktop\Resource\Code\geekforgeeks\data\raw\calendar.csv.gz")

print(calendar.shape)
print(calendar.columns.tolist())
print(calendar.head())
# Out:
# (156585, 7)
# ['listing_id', 'date', 'available', 'price', 'adjusted_price', 'minimum_nights', 'maximum_nights']
#    listing_id        date available   price  adjusted_price  minimum_nights  \
# 0     2992450  2025-01-05         f  $70.00             NaN              28
# 1     2992450  2025-01-06         f  $70.00             NaN              28
# 2     2992450  2025-01-07         f  $70.00             NaN              28
# 3     2992450  2025-01-08         f  $70.00             NaN              28
# 4     2992450  2025-01-09         f  $70.00             NaN              28
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
calendar["date"] = pd.to_datetime(calendar["date"])

print("Start:", calendar["date"].min())
print("End:", calendar["date"].max())
# Out:
# Start: 2025-01-05 00:00:00
# End: 2026-01-15 00:00:00
